# %% [markdown]
# 1. Mengimpor library-library yang diperlukan untuk pemodelan ML

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Menentukan dan menampilkan dataset yang akan dipakai pada sebuah
# dataframe. Dalam kasus ini data mobil diperoleh dari Kaggle. Amati data yang
# ditampilkan

# %%
#https://www.kaggle.com/datasets/goyalshalini93/car-data
df_mobil = pd.read_csv("CarPride.csv")
df_mobil
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %% [markdown]
# 3. Cek apakah ada data yang kosong pada dataset tersebut.

# %%
missing_values = df_mobil.isnull().sum()

print("Jumlah data kosong per kolom:")
print(missing_values)
# Out:
# Jumlah data kosong per kolom:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# 4.  Tampilkan nilai count, mean, std, nilai min, kuartil 1 (25%), median (50%),
# kuartil 3 (75%), nilai max pada dataset tersebut sehingga hasilnya pada
# gambar di bawah ini.

# %%
statistik_deskriptif = df_mobil.describe()

median_values = df_mobil.select_dtypes(include=np.number).median()
statistik_deskriptif.loc['50%'] = median_values

print("Statistik deskriptif:")
print(statistik_deskriptif)
# Out:
# Statistik deskriptif:
#        car_ID  symboling  wheelbase  carlength  carwidth  carheight  \
# count  205.00     205.00     205.00     205.00    205.00     205.00
# mean   103.00       0.83      98.76     174.05     65.91      53.72
# std     59.32       1.25       6.02      12.34      2.15       2.44
# min      1.00      -2.00      86.60     141.10     60.30      47.80
# 25%     52.00       0.00      94.50     166.30     64.10      52.00
# 50%    103.00       1.00      97.00     173.20     65.50      54.10
# 75%    154.00       2.00     102.40     183.10     66.90      55.50
# max    205.00       3.00     120.90     208.10     72.30      59.80
#
#        curbweight  enginesize  boreratio  stroke  compressionratio  \
# count      205.00      205.00     205.00  205.00            205.00
# mean     2,555.57      126.91       3.33    3.26             10.14
# std        520.68       41.64       0.27    0.31              3.97
# min      1,488.00       61.00       2.54    2.07              7.00
# 25%      2,145.00       97.00       3.15    3.11              8.60
# 50%      2,414.00      120.00       3.31    3.29              9.00
# 75%      2,935.00      141.00       3.58    3.41              9.40
# max      4,066.00      326.00       3.94    4.17             23.00
#
#        horsepower  peakrpm  citympg  highwaympg     price
# count      205.00   205.00   205.00      205.00    205.00
# mean       104.12 5,125.12    25.22       30.75 13,276.71
# std         39.54   476.99     6.54        6.89  7,988.85
# min         48.00 4,150.00    13.00       16.00  5,118.00
# 25%         70.00 4,800.00    19.00       25.00  7,788.00
# 50%         95.00 5,200.00    24.00       30.00 10,295.00
# 75%        116.00 5,500.00    30.00       34.00 16,503.00
# max        288.00 6,600.00    49.00       54.00 45,400.00

# %% [markdown]
# 5. Tampilkan semua tipe data pada dataset tersebut.

# %%
print("Tipe data setiap kolom:")
print(df_mobil.dtypes)

from IPython.display import display
display(df_mobil.dtypes.to_frame(name='Tipe Data'))
# Out:
# Tipe data setiap kolom:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object
#                  Tipe Data
# car_ID               int64
# symboling            int64
# CarName             object
# fueltype            object
# aspiration          object
# doornumber          object
# carbody             object
# drivewheel          object
# enginelocation      object
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
# enginetype          object
# cylindernumber      object
# enginesize           int64
# fuelsystem          object
# boreratio          float64
# stroke             float64
# compressionratio   float64
# horsepower           int64
# peakrpm              int64
# citympg              int64
# highwaympg           int64
# price              float64

# %% [markdown]
# 6. Tampilkan grafik untuk menunjukkan distribusi harga mobil.

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.title('Car Pride Distribution Plot')
sns.histplot(df_mobil.price)

plt.show()

# %% [markdown]
# 7. Tampilkan grafik sebaran nama-nama mobil yang ada pada dataset.

# %%
car_counts = df_mobil['CarName'].value_counts()

plt.figure(figsize=(10,6))
car_counts.plot(kind="bar")
plt.title("CarName Distribution")
plt.xlabel("CarName")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# 8. Tampilkan 10 nama mobil terbanyak pada dataset.

# %%
car_counts = df_mobil['CarName'].value_counts()

top_10_cars = car_counts.head(10)
print("10 Nama Mobil Terbanyak:")
print(top_10_cars)

plt.figure(figsize=(10,6))
top_10_cars.plot(kind="bar", color="skyblue")
plt.title("10 Nama Mobil Terbanyak")
plt.xlabel("Nama Mobil")
plt.ylabel("Jumlah")
plt.xticks(rotation=45)
plt.show()
# Out:
# 10 Nama Mobil Terbanyak:
# CarName
# peugeot 504             6
# toyota corolla          6
# toyota corona           6
# subaru dl               4
# mitsubishi outlander    3
# mazda 626               3
# honda civic             3
# mitsubishi mirage g4    3
# mitsubishi g4           3
# toyota mark ii          3
# Name: count, dtype: int64

# %% [markdown]
# 9. Buatkan sebuah world cloud untuk nama-nama mobil yang ada seperti pada
# gambar di bawah ini.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Gabungkan semua nama mobil menjadi satu string
car_names_text = " ".join(df_mobil['CarName'])

# Membuat Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(car_names_text)

# Menampilkan Word Cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")  # Menghilangkan sumbu
plt.title("Word Cloud untuk Nama Mobil", fontsize=16)
plt.show()

# %% [markdown]
# 10. Tampilkan sebuah scatter plot untuk menunjukkan hubungan antara data
# highwaympg dengan price pada dataset. Jelaskan arti dari scatter plot
# tersebut.

# %%
plt.scatter(df_mobil['highwaympg'], df_mobil['price'])
plt.xlabel('highwaympg')
plt.ylabel('price')
plt.show()

# %% [markdown]
# 11. Pada kasus ini, digunakan metode Linear Regression untuk membangun
# model prediksi harga mobil.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# 12. Tentukan variable independent (X) sebagai inputan yakni 'highwaympg',
# 'curbweight', dan 'horsepower', dan variable dependent (y) sebagai output
# dari model ini yakni 'price'.

# %%
x = df_mobil[['highwaympg','curbweight','horsepower']]
y = df_mobil['price']

# %% [markdown]
# 13. Lalu bagi dataset menjadi data pelatihan (X_train dan y_train) dan data
# pengujian (X_test dan y_test). Data pengujian akan diambil 20% dari total data
# menggunakan random state 42.

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# %% [markdown]
# 14. Buat objek model menggunakan class LinearRegression, dan lakukan
# pelatihan pada fitur data pelatihan (X) dan target data pelatihan (y), yang
# berisi nilai target yang akan diprediksi yakni ‘price’.

# %%
model_regresi = LinearRegression()
model_regresi.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 15. Lakukan prediksi menggunakan model regresi linear yang telah dilatih pada
# data pengujian (X_test).

# %%
model_regresi_pred = model_regresi.predict(X_test)

# %% [markdown]
# 16. Visualisasikan hasil prediksi dari model regresi linear tersebut. Pada sumbu x
# (X_test.iloc[:, 0]), digunakan nilai 'highwaympg' dari data pengujian (X_test),
# dan pada sumbu y (model_regresi_pred), digunakan nilai prediksi harga mobil
# 4
# (price) yang dihasilkan oleh model. Jelaskan perbandingan hasil scatter plot
# ini dengan no 10.

# %%
plt.scatter(X_test.iloc[:, 0], y_test, label = 'Actual Prices', color='blue')
plt.scatter(X_test.iloc[:, 0], model_regresi_pred, label = 'Predicted Prices', color='red')
plt.xlabel('highwaympg')
plt.xlabel('price')
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 17. Lakukan tes prediksi harga mobil menggunakan inputan nilai-nilai
# highwaympg = 32, curbweight = 2338, dan horsepower = 75. Berapa prediksi
# harganya?

# %%
input_data = pd.DataFrame([[32, 2338, 75]], columns=['highwaympg', 'curbweight', 'horsepower'])
harga_X = model_regresi.predict(input_data)
print(f"Prediksi harga mobil: ${harga_X[0]:,.2f}")
# Out:
# Prediksi harga mobil: $8,571.94

# %% [markdown]
# 18. Ubah nilai array tersebut menjadi integer.

# %%
input_data = pd.DataFrame([[32, 2338, 75]], columns=['highwaympg', 'curbweight', 'horsepower'])
harga_X = model_regresi.predict(input_data)
prediksi_harga = int(harga_X[0])
print(f"Prediksi harga mobil: ${prediksi_harga:,}")
# Out:
# Prediksi harga mobil: $8,571

# %% [markdown]
# 19. Lakukan evaluasi untuk mengetahui nilai MAE, MSE, dan RMSE.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae = mean_absolute_error(y_test, model_regresi_pred)
print(f'Mean Absolute Error (MAE): 1  {mae:.2f}')
mse = mean_squared_error(y_test, model_regresi_pred)
print(f'Mean Squared Error (MSE): {mse:.2f}')
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# Mean Absolute Error (MAE): 1  2808.47
# Mean Squared Error (MSE): 13759450.64
# Root Mean Squared Error (RMSE): 3709.37

# %% [markdown]
# 20.
# Evaluasi model regresi dilakukan menggunakan MAE, MSE, dan RMSE untuk mengukur performanya dalam memprediksi harga mobil. MAE menunjukkan rata-rata kesalahan prediksi dalam satuan asli, sehingga mudah dipahami; misalnya, jika MAE adalah 1500, rata-rata prediksi meleset $1500 dari nilai sebenarnya. MSE menghitung rata-rata kesalahan kuadrat, lebih sensitif terhadap outlier, tetapi sulit diinterpretasikan karena satuannya adalah kuadrat. RMSE, sebagai akar kuadrat dari MSE, mengembalikan satuan ke skala asli dan memberikan bobot lebih besar pada kesalahan besar.
#
# Semakin kecil nilai MAE, MSE, dan RMSE, semakin baik performa model. Jika nilainya tinggi, ini menunjukkan perlunya perbaikan, seperti menambah fitur relevan, normalisasi data, atau mencoba model yang lebih kompleks. Evaluasi ini membantu memahami seberapa akurat model dan langkah-langkah yang diperlukan untuk peningkatan.
